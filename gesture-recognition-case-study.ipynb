# %% [markdown]
# # Gesture Recognition Case Study
#
#  * **Dharmendra Kumar – Group Facilitator**
#  * **Ashwin Kumar h**
#
#
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %% [markdown]
# <h3>Problem Statement</h3>
#
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.
# Problem Statement
#
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# <table>
# <thead>
# <tr>
# <th>Gesture</th>
# <th>Corresponding Action</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Thumbs Up</td>
# <td>Increase the volume.</td>
# </tr>
# <tr>
# <td>Thumbs Down</td>
# <td>Decrease the volume.</td>
# </tr>
# <tr>
# <td>Left Swipe</td>
# <td>'Jump' backwards 10 seconds.</td>
# </tr>
# <tr>
# <td>Right Swipe</td>
# <td>'Jump' forward 10 seconds.</td>
# </tr>
# <tr>
# <td>Stop</td>
# <td>Pause the movie.</td>
# </tr>
# </tbody>
# </table>
#
# The data is in a zip file. The zip file contains a 'train' and a 'val' folder with two CSV files for the two folders. These folders are in turn divided into subfolders where each subfolder represents a video of a particular gesture. Each subfolder, i.e. a video, contains 30 frames (or images). Note that all images in a particular video subfolder have the same dimensions but different videos may have different dimensions. Specifically, videos have two types of dimensions - either 360x360 or 120x160 (depending on the webcam used to record the videos). Hence, you will need to do some pre-processing to standardise the videos.
#
# <b>Each row of the CSV file represents one video and contains three main pieces of information - the name of the subfolder containing the 30 images of the video, the name of the gesture and the numeric label (between 0-4) of the video.</b>
#
# Your task is to train a model on the 'train' folder which performs well on the 'val' folder as well (as usually done in ML projects). We have withheld the test folder for evaluation purposes - your final model's performance will be tested on the 'test' set.

# %%
## Checking the GPU configuration

# !nvidia-smi
# Out:
# Mon Feb  6 05:31:55 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Importing the necessary libraries
import numpy as np
import os
from skimage.transform import resize
from imageio import imread
import datetime
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#We set the random seed so that the results don't vary drastically.
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
device_name = tf.test.gpu_device_name()
if "GPU" not in device_name:
    print("GPU device not found")
else:
    print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0
# 2023-02-06 06:00:43.085350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 06:00:43.085922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 06:00:43.086321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 06:00:43.086793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 06:00:43.087139: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 06:00:43.087423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the batch_size here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
#loading .csv file 
train_doc = np.random.permutation(open('../input/gesturerecognition/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('../input/gesturerecognition/Project_data/val.csv').readlines())
batch_size = 64

# %%
# function to plot the training/validation accuracies/losses.
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].grid()
    axes[0].legend(['loss','val_loss'])
    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].grid()
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# # Generator
#
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with img_idx, y,z and normalization such that you get high accuracy.

# %%
def cropResize(image, y, z):
    h, w = image.shape
    
    # if smaller image crop at center for 120x120
    if w == 160:
        image = image[:120, 20:140]

    # resize every image
    return resize(image, (y,z))

# %%
#normalizing the images
def normalizeImage(image):
    # applying normalization
    return image/255.0

# %%
#preprocessImage function is defined for cropping
def preprocessImage(image, y, z):
    return normalizeImage(cropResize(image, y, z))

# %%
def make3dFilter(x):
    return tuple([x]*3)

def make2dFilter(x):
    return tuple([x]*2)

# %%
  #normalizing the images
def getBatchData(source_path, t, batch, batch_size, img_tensor):
    [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
    img_idx = img_tensor[0]
    batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    for folder in range(batch_size): # iterate over the batch_size
        imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
        for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
            image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes

            # separate preprocessImage function is defined for cropping, resizing and normalizing images
            batch_data[folder,idx,:,:,0] = preprocessImage(image[:, :, 0], y, z)
            batch_data[folder,idx,:,:,1] = preprocessImage(image[:, :, 1], y, z)
            batch_data[folder,idx,:,:,2] = preprocessImage(image[:, :, 2], y, z)

        batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
    return batch_data, batch_labels

# %%
# MOST IMPORTANT PART HERE - The generator function
def generator(source_path, folder_list, batch_size, img_tensor):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list)/batch_size)
        for batch in range(num_batches): # we iterate over the number of batches
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)
        
        # write the code for the remaining data points which are left after full batches
        # checking if any remaining batches are there or not
        if len(folder_list)%batch_size != 0:
            # updated the batch size and yield
            batch_size = len(folder_list)%batch_size
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)

# %% [markdown]
# <b>Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.</b>

# %%
curr_dt_time = datetime.datetime.now()
train_path = '../input/gesturerecognition/Project_data/train'
val_path = '../input/gesturerecognition/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %%
def getImgTensor(n_frames):
    img_idx = np.round(np.linspace(0, 29, n_frames)).astype(int)
    return [img_idx, 100, 100, 3]

# define image tensor size
img_tensor = getImgTensor(20)
print ('# img_tensor =', img_tensor)
# Out:
# # img_tensor = [array([ 0,  2,  3,  5,  6,  8,  9, 11, 12, 14, 15, 17, 18, 20, 21, 23, 24,
#        26, 27, 29]), 100, 100, 3]

# %% [markdown]
# <h3>Generator Validation</h3>
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with img_idx, y,z and normalization such that you get high accuracy.

# %%
# check complete batch shape
sample_generator = generator(train_path, train_doc, batch_size, img_tensor)
sample_batch_data, sample_batch_labels = next(sample_generator)
print(sample_batch_data.shape)

# validation batch sample
sample_val_generator = generator(val_path, val_doc, batch_size, img_tensor)
sample_val_batch_data, sample_val_batch_labels = next(sample_val_generator)
print(sample_val_batch_data.shape)
# Out:
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# (64, 20, 100, 100, 3)
# Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# (64, 20, 100, 100, 3)

# %%
# plot generated sample images
fig, ax = plt.subplots(1,2)
ax[0].imshow(sample_val_batch_data[0,1,:,:,:])
ax[1].imshow(sample_val_batch_data[0,3,:,:,:])
plt.show()

# %%
def plotModelHistory(h):
    fig, ax = plt.subplots(1, 2, figsize=(15,4))
    ax[0].plot(h.history['loss'])   
    ax[0].plot(h.history['val_loss'])
    ax[0].legend(['loss','val_loss'])
    ax[0].title.set_text("Train loss vs Validation loss")

    ax[1].plot(h.history['categorical_accuracy'])   
    ax[1].plot(h.history['val_categorical_accuracy'])
    ax[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    ax[1].title.set_text("Train accuracy vs Validation accuracy")
    plt.show()

    print("Max. Training Accuracy", max(h.history['categorical_accuracy']))
    print("Max. Validaiton Accuracy", max(h.history['val_categorical_accuracy']))

# %% [markdown]
# # Model Building
#
# Here you make the model using different functionalities that Keras provides. Remember to use Conv3D and MaxPooling3D and not Conv2D and Maxpooling2D for a 3D convolution model. You would want to use TimeDistributed while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from tensorflow import keras
from keras.layers import Dropout
import tensorflow as tf

# %% [markdown]
# <h3>Base Model</h3>

# %%
#write your model here
def defineModel(img_tensor):
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_3 (Conv3D)            (None, 16, 96, 96, 16)    6016
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 8, 48, 48, 16)     0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 48, 48, 16)     64
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 6, 46, 46, 32)     13856
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 6, 23, 23, 32)     0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 23, 23, 32)     128
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 4, 21, 21, 64)     55360
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 4, 11, 11, 64)     0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 11, 11, 64)     256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 4,050,085
# Trainable params: 4,049,477
# Non-trainable params: 608
# _________________________________________________________________

# %%
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# <h3>Model Callbacks Setup</h3>

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)

earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
callbacks_list = [checkpoint, LR, earlystop]

# %% [markdown]
# <h3>Model 1 - Frames-16, Epoc-20</h3>

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)


if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model1 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d1")
model1.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())

model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_6 (Conv3D)            (None, 12, 96, 96, 16)    6016
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 6, 48, 48, 16)     0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 6, 48, 48, 16)     64
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 4, 46, 46, 32)     13856
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 4, 23, 23, 32)     0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 23, 23, 32)     128
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 2, 21, 21, 64)     55360
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 2, 11, 11, 64)     0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 11, 11, 64)     256
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 15488)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1982592
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 2,067,621
# Trainable params: 2,067,013
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# 2023-02-06 06:04:36.309576: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 2023-02-06 06:04:38.691466: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 11/11 [==============================] - ETA: 0s - loss: 1.5233 - categorical_accuracy: 0.4781 Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# 11/11 [==============================] - 147s 14s/step - loss: 1.5233 - categorical_accuracy: 0.4781 - val_loss: 2.4251 - val_categorical_accuracy: 0.2700
#
# Epoch 00001: val_loss improved from inf to 2.42505, saving model to model_init_2023-02-0606_01_12.245131/model-00001-1.52331-0.47813-2.42505-0.27000.h5
# Epoch 2/20
# 11/11 [==============================] - 48s 5s/step - loss: 1.1057 - categorical_accuracy: 0.5731 - val_loss: 5.9321 - val_categorical_accuracy: 0.1875
#
# Epoch 00002: val_loss did not improve from 2.42505
# Epoch 3/20
# 11/11 [==============================] - 42s 4s/step - loss: 1.1480 - categorical_accuracy: 0.5573 - val_loss: 3.5216 - val_categorical_accuracy: 0.2679
#
# Epoch 00003: val_loss did not improve from 2.42505
# Epoch 4/20
# 11/11 [==============================] - 34s 3s/step - loss: 0.9567 - categorical_accuracy: 0.6352 - val_loss: 1.8771 - val_categorical_accuracy: 0.1875
#
# Epoch 00004: val_loss improved from 2.42505 to 1.87712, saving model to model_init_2023-02-0606_01_12.245131/model-00004-0.95671-0.63519-1.87712-0.18750.h5
# Epoch 5/20
# 11/11 [==============================] - 34s 3s/step - loss: 0.7446 - categorical_accuracy: 0.7416 - val_loss: 2.1333 - val_categorical_accuracy: 0.1562
#
# Epoch 00005: val_loss did not improve from 1.87712
# Epoch 6/20
# 11/11 [==============================] - 26s 3s/step - loss: 0.9830 - categorical_accuracy: 0.6555 - val_loss: 1.8482 - val_categorical_accuracy: 0.3750
#
# Epoch 00006: val_loss improved from 1.87712 to 1.84815, saving model to model_init_2023-02-0606_01_12.245131/model-00006-0.98303-0.65550-1.84815-0.37500.h5
# Epoch 7/20
# 11/11 [==============================] - 29s 3s/step - loss: 0.7985 - categorical_accuracy: 0.6847 - val_loss: 1.8938 - val_categorical_accuracy: 0.5000
#
# Epoch 00007: val_loss did not improve from 1.84815
# Epoch 8/20
# 11/11 [==============================] - 25s 2s/step - loss: 0.6037 - categorical_accuracy: 0.7968 - val_loss: 3.3030 - val_categorical_accuracy: 0.3750
#
# Epoch 00008: val_loss did not improve from 1.84815
# Epoch 9/20
# 11/11 [==============================] - 27s 3s/step - loss: 0.7798 - categorical_accuracy: 0.6738 - val_loss: 1.9950 - val_categorical_accuracy: 0.1250
#
# Epoch 00009: val_loss did not improve from 1.84815
# Epoch 10/20
# 11/11 [==============================] - 25s 2s/step - loss: 0.8625 - categorical_accuracy: 0.6845 - val_loss: 3.1454 - val_categorical_accuracy: 0.1250
#
# Epoch 00010: val_loss did not improve from 1.84815
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 11/20
# 11/11 [==============================] - 23s 2s/step - loss: 0.7139 - categorical_accuracy: 0.7380 - val_loss: 2.7077 - val_categorical_accuracy: 0.3750
#
# Epoch 00011: val_loss did not improve from 1.84815
# Epoch 12/20
# 11/11 [==============================] - 25s 2s/step - loss: 0.5927 - categorical_accuracy: 0.7861 - val_loss: 2.4680 - val_categorical_accuracy: 0.1250
#
# Epoch 00012: val_loss did not improve from 1.84815
# Epoch 13/20
# 11/11 [==============================] - 26s 3s/step - loss: 0.6025 - categorical_accuracy: 0.7701 - val_loss: 2.8244 - val_categorical_accuracy: 0.2500
#
# Epoch 00013: val_loss did not improve from 1.84815
# Epoch 14/20
# 11/11 [==============================] - 22s 2s/step - loss: 0.5052 - categorical_accuracy: 0.8396 - val_loss: 1.7337 - val_categorical_accuracy: 0.3750
#
# Epoch 00014: val_loss improved from 1.84815 to 1.73372, saving model to model_init_2023-02-0606_01_12.245131/model-00014-0.50523-0.83957-1.73372-0.37500.h5
# Epoch 15/20
# 11/11 [==============================] - 25s 2s/step - loss: 0.3712 - categorical_accuracy: 0.8770 - val_loss: 1.9661 - val_categorical_accuracy: 0.2500
#
# Epoch 00015: val_loss did not improve from 1.73372
# Epoch 16/20
# 11/11 [==============================] - 24s 2s/step - loss: 0.4694 - categorical_accuracy: 0.8396 - val_loss: 1.8201 - val_categorical_accuracy: 0.2500
#
# Epoch 00016: val_loss did not improve from 1.73372
# Epoch 17/20
# 11/11 [==============================] - 26s 3s/step - loss: 0.4321 - categorical_accuracy: 0.8663 - val_loss: 2.2123 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: val_loss did not improve from 1.73372
# Epoch 18/20
# 11/11 [==============================] - 26s 3s/step - loss: 0.3146 - categorical_accuracy: 0.9037 - val_loss: 1.0763 - val_categorical_accuracy: 0.6250
#
# Epoch 00018: val_loss improved from 1.73372 to 1.07627, saving model to model_init_2023-02-0606_01_12.245131/model-00018-0.31459-0.90374-1.07627-0.62500.h5
# Epoch 19/20
# 11/11 [==============================] - 25s 2s/step - loss: 0.3783 - categorical_accuracy: 0.8770 - val_loss: 3.0971 - val_categorical_accuracy: 0.1250
#
# Epoch 00019: val_loss did not improve from 1.07627
# Epoch 20/20
# 11/11 [==============================] - 25s 2s/step - loss: 0.3830 - categorical_accuracy: 0.8610 - val_loss: 2.3739 - val_categorical_accuracy: 0.5000
#
# Epoch 00020: val_loss did not improve from 1.07627

# %%
plotModelHistory(model1_history)
# Out:
# Max. Training Accuracy 0.903743326663971
# Max. Validaiton Accuracy 0.625

# %% [markdown]
# <h3>Model 2: Frames-20, Epocs-25</h3>

# %%
n_frames = 20
num_epochs = 25
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model2 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d2")
model2.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model2.summary())

model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_9 (Conv3D)            (None, 16, 96, 96, 16)    6016
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 8, 48, 48, 16)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 48, 48, 16)     64
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 6, 46, 46, 32)     13856
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 6, 23, 23, 32)     0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 6, 23, 23, 32)     128
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 4, 21, 21, 64)     55360
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 4, 11, 11, 64)     0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 4, 11, 11, 64)     256
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 4,050,085
# Trainable params: 4,049,477
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# Epoch 1/25
# 11/11 [==============================] - ETA: 0s - loss: 1.5182 - categorical_accuracy: 0.4253 Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# 11/11 [==============================] - 154s 15s/step - loss: 1.5182 - categorical_accuracy: 0.4253 - val_loss: 6.0088 - val_categorical_accuracy: 0.2400
#
# Epoch 00001: val_loss did not improve from 1.07627
# Epoch 2/25
# 11/11 [==============================] - 60s 6s/step - loss: 1.0740 - categorical_accuracy: 0.5613 - val_loss: 4.9604 - val_categorical_accuracy: 0.2500
#
# Epoch 00002: val_loss did not improve from 1.07627
# Epoch 3/25
# 11/11 [==============================] - 57s 6s/step - loss: 1.0219 - categorical_accuracy: 0.5573 - val_loss: 7.5565 - val_categorical_accuracy: 0.1964
#
# Epoch 00003: val_loss did not improve from 1.07627
# Epoch 4/25
# 11/11 [==============================] - 42s 4s/step - loss: 0.8658 - categorical_accuracy: 0.6652 - val_loss: 3.4788 - val_categorical_accuracy: 0.3438
#
# Epoch 00004: val_loss did not improve from 1.07627
# Epoch 5/25
# 11/11 [==============================] - 41s 4s/step - loss: 0.7945 - categorical_accuracy: 0.7033 - val_loss: 1.8940 - val_categorical_accuracy: 0.2500
#
# Epoch 00005: val_loss did not improve from 1.07627
# Epoch 6/25
# 11/11 [==============================] - 36s 4s/step - loss: 0.7450 - categorical_accuracy: 0.6986 - val_loss: 1.4622 - val_categorical_accuracy: 0.5000
#
# Epoch 00006: val_loss did not improve from 1.07627
# Epoch 7/25
# 11/11 [==============================] - 32s 3s/step - loss: 0.8388 - categorical_accuracy: 0.6847 - val_loss: 2.6419 - val_categorical_accuracy: 0.1250
#
# Epoch 00007: val_loss did not improve from 1.07627
# Epoch 8/25
# 11/11 [==============================] - 29s 3s/step - loss: 0.7628 - categorical_accuracy: 0.6738 - val_loss: 2.0006 - val_categorical_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 1.07627
# Epoch 9/25
# 11/11 [==============================] - 29s 3s/step - loss: 0.7362 - categorical_accuracy: 0.7005 - val_loss: 3.6149 - val_categorical_accuracy: 0.3750
#
# Epoch 00012: val_loss did not improve from 0.96952
# Epoch 13/25
# 11/11 [==============================] - 31s 3s/step - loss: 0.8863 - categorical_accuracy: 0.6524 - val_loss: 6.0328 - val_categorical_accuracy: 0.2500
#
# Epoch 00013: val_loss did not improve from 0.96952
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/25
# 11/11 [==============================] - 31s 3s/step - loss: 0.8118 - categorical_accuracy: 0.6952 - val_loss: 2.6677 - val_categorical_accuracy: 0.2500
#
# Epoch 00014: val_loss did not improve from 0.96952
# Epoch 15/25
# 11/11 [==============================] - 31s 3s/step - loss: 0.5425 - categorical_accuracy: 0.8289 - val_loss: 2.6915 - val_categorical_accuracy: 0.5000
#
# Epoch 00015: val_loss did not improve from 0.96952
# Epoch 16/25
# 11/11 [==============================] - 32s 3s/step - loss: 0.4855 - categorical_accuracy: 0.8075 - val_loss: 1.4227 - val_categorical_accuracy: 0.5000
#
# Epoch 00016: val_loss did not improve from 0.96952
# Epoch 17/25
# 11/11 [==============================] - 32s 3s/step - loss: 0.5854 - categorical_accuracy: 0.7861 - val_loss: 1.5274 - val_categorical_accuracy: 0.3750
#
# Epoch 00017: val_loss did not improve from 0.96952
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18/25
# 11/11 [==============================] - 30s 3s/step - loss: 0.5527 - categorical_accuracy: 0.7540 - val_loss: 1.6286 - val_categorical_accuracy: 0.3750
#
# Epoch 00018: val_loss did not improve from 0.96952
# Epoch 19/25
# 11/11 [==============================] - 30s 3s/step - loss: 0.5393 - categorical_accuracy: 0.7914 - val_loss: 1.4565 - val_categorical_accuracy: 0.3750
#
# Epoch 00019: val_loss did not improve from 0.96952
# Epoch 00019: early stopping

# %%
plotModelHistory(model2_history)
# Out:
# Max. Training Accuracy 0.8288770318031311
# Max. Validaiton Accuracy 0.625

# %% [markdown]
# <h3>Model 3: Frames-25, Epocs-20, Reduced parameters</h3>

# %%
n_frames = 25
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model2 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d2")
model2.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model2.summary())

model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_12 (Conv3D)           (None, 21, 96, 96, 16)    6016
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 11, 48, 48, 16)    0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 11, 48, 48, 16)    64
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 9, 46, 46, 32)     13856
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 9, 23, 23, 32)     0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 9, 23, 23, 32)     128
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 7, 21, 21, 64)     55360
# _________________________________________________________________
# max_pooling3d_14 (MaxPooling (None, 7, 11, 11, 64)     0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 7, 11, 11, 64)     256
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 54208)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               6938752
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 7,023,781
# Trainable params: 7,023,173
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.4798 - categorical_accuracy: 0.4676 Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# 11/11 [==============================] - 179s 18s/step - loss: 1.4798 - categorical_accuracy: 0.4676 - val_loss: 3.2315 - val_categorical_accuracy: 0.2400
#
# Epoch 00001: val_loss did not improve from 0.96952
# Epoch 2/20
# 11/11 [==============================] - 74s 7s/step - loss: 0.9280 - categorical_accuracy: 0.6166 - val_loss: 4.1422 - val_categorical_accuracy: 0.2344
#
# Epoch 00002: val_loss did not improve from 0.96952
# Epoch 3/20
# 11/11 [==============================] - 69s 7s/step - loss: 1.2513 - categorical_accuracy: 0.5494 - val_loss: 8.8928 - val_categorical_accuracy: 0.2143
#
# Epoch 00003: val_loss did not improve from 0.96952
# Epoch 4/20
# 11/11 [==============================] - 55s 5s/step - loss: 1.1992 - categorical_accuracy: 0.5708 - val_loss: 8.6220 - val_categorical_accuracy: 0.2812
#
# Epoch 00004: val_loss did not improve from 0.96952
# Epoch 5/20
# 11/11 [==============================] - 51s 5s/step - loss: 1.0512 - categorical_accuracy: 0.5837 - val_loss: 6.7631 - val_categorical_accuracy: 0.2812
#
# Epoch 00005: val_loss did not improve from 0.96952
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/20
# 11/11 [==============================] - 43s 4s/step - loss: 1.0231 - categorical_accuracy: 0.6316 - val_loss: 2.1659 - val_categorical_accuracy: 0.6250
#
# Epoch 00006: val_loss did not improve from 0.96952
# Epoch 7/20
# 11/11 [==============================] - 44s 4s/step - loss: 0.7363 - categorical_accuracy: 0.6995 - val_loss: 4.5365 - val_categorical_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 0.96952
# Epoch 8/20
# 11/11 [==============================] - 38s 4s/step - loss: 0.7146 - categorical_accuracy: 0.7166 - val_loss: 2.1439 - val_categorical_accuracy: 0.3750
#
# Epoch 00008: val_loss did not improve from 0.96952
# Epoch 9/20
# 11/11 [==============================] - 38s 4s/step - loss: 0.7375 - categorical_accuracy: 0.7326 - val_loss: 2.8990 - val_categorical_accuracy: 0.2500
#
# Epoch 00009: val_loss did not improve from 0.96952
# Epoch 10/20
# 11/11 [==============================] - 40s 4s/step - loss: 0.5836 - categorical_accuracy: 0.8075 - val_loss: 2.2348 - val_categorical_accuracy: 0.1250
#
# Epoch 00010: val_loss did not improve from 0.96952
# Epoch 11/20
# 11/11 [==============================] - 40s 4s/step - loss: 0.6597 - categorical_accuracy: 0.7487 - val_loss: 2.1987 - val_categorical_accuracy: 0.2500
#
# Epoch 00011: val_loss did not improve from 0.96952
# Epoch 12/20
# 11/11 [==============================] - 39s 4s/step - loss: 0.5626 - categorical_accuracy: 0.8235 - val_loss: 2.4774 - val_categorical_accuracy: 0.2500
#
# Epoch 00012: val_loss did not improve from 0.96952
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 13/20
# 11/11 [==============================] - 38s 4s/step - loss: 0.6219 - categorical_accuracy: 0.7701 - val_loss: 1.4478 - val_categorical_accuracy: 0.5000
#
# Epoch 00013: val_loss did not improve from 0.96952
# Epoch 14/20
# 11/11 [==============================] - 38s 4s/step - loss: 0.5510 - categorical_accuracy: 0.8075 - val_loss: 2.3895 - val_categorical_accuracy: 0.3750
#
# Epoch 00014: val_loss did not improve from 0.96952
# Epoch 15/20
# 11/11 [==============================] - 40s 4s/step - loss: 0.5628 - categorical_accuracy: 0.8128 - val_loss: 0.7944 - val_categorical_accuracy: 0.7500
#
# Epoch 00015: val_loss improved from 0.96952 to 0.79441, saving model to model_init_2023-02-0606_01_12.245131/model-00015-0.56282-0.81283-0.79441-0.75000.h5
# Epoch 16/20
# 11/11 [==============================] - 41s 4s/step - loss: 0.6836 - categorical_accuracy: 0.7754 - val_loss: 2.4670 - val_categorical_accuracy: 0.2500
#
# Epoch 00016: val_loss did not improve from 0.79441
# Epoch 17/20
# 11/11 [==============================] - 37s 4s/step - loss: 0.5707 - categorical_accuracy: 0.7701 - val_loss: 2.2360 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: val_loss did not improve from 0.79441
# Epoch 18/20
# 11/11 [==============================] - 38s 4s/step - loss: 0.5760 - categorical_accuracy: 0.7594 - val_loss: 1.4234 - val_categorical_accuracy: 0.5000
#
# Epoch 00018: val_loss did not improve from 0.79441
# Epoch 19/20
# 11/11 [==============================] - 39s 4s/step - loss: 0.5141 - categorical_accuracy: 0.8128 - val_loss: 1.8247 - val_categorical_accuracy: 0.5000
#
# Epoch 00019: val_loss did not improve from 0.79441
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 20/20
# 11/11 [==============================] - 39s 4s/step - loss: 0.5830 - categorical_accuracy: 0.7487 - val_loss: 1.5198 - val_categorical_accuracy: 0.5000
#
# Epoch 00020: val_loss did not improve from 0.79441

# %%
plotModelHistory(model2_history)
# Out:
# Max. Training Accuracy 0.8235294222831726
# Max. Validaiton Accuracy 0.75

# %% [markdown]
# <h3>Model 4: Frames-20, Same pooling in Conv3D layer</h3>

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model4 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(128, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d4")
model4.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model4.summary())

model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_15 (Conv3D)           (None, 20, 100, 100, 16)  1312
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 10, 50, 50, 16)    0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 10, 50, 50, 16)    64
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 10, 50, 50, 32)    13856
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 5, 25, 25, 32)     0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 5, 25, 25, 32)     128
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 5, 25, 25, 64)     55360
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 3, 13, 13, 64)     0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 3, 13, 13, 64)     256
# _________________________________________________________________
# conv3d_18 (Conv3D)           (None, 3, 13, 13, 128)    221312
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 2, 7, 7, 128)      0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 2, 7, 7, 128)      512
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               1605760
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 1,907,909
# Trainable params: 1,907,045
# Non-trainable params: 864
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.5048 - categorical_accuracy: 0.4525 Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# 11/11 [==============================] - 129s 13s/step - loss: 1.5048 - categorical_accuracy: 0.4525 - val_loss: 1.5739 - val_categorical_accuracy: 0.2200
#
# Epoch 00001: val_loss did not improve from 0.79441
# Epoch 2/20
# 11/11 [==============================] - 54s 5s/step - loss: 0.9941 - categorical_accuracy: 0.6206 - val_loss: 2.0758 - val_categorical_accuracy: 0.1875
#
# Epoch 00002: val_loss did not improve from 0.79441
# Epoch 3/20
# 11/11 [==============================] - 53s 5s/step - loss: 0.9833 - categorical_accuracy: 0.6166 - val_loss: 1.7732 - val_categorical_accuracy: 0.2321
#
# Epoch 00003: val_loss did not improve from 0.79441
# Epoch 4/20
# 11/11 [==============================] - 42s 4s/step - loss: 0.8527 - categorical_accuracy: 0.6652 - val_loss: 2.0343 - val_categorical_accuracy: 0.3125
#
# Epoch 00004: val_loss did not improve from 0.79441
# Epoch 5/20
# 11/11 [==============================] - 41s 4s/step - loss: 0.8275 - categorical_accuracy: 0.6603 - val_loss: 2.0230 - val_categorical_accuracy: 0.4375
#
# Epoch 00005: val_loss did not improve from 0.79441
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/20
# 11/11 [==============================] - 33s 3s/step - loss: 0.8179 - categorical_accuracy: 0.6842 - val_loss: 3.8141 - val_categorical_accuracy: 0.1250
#
# Epoch 00006: val_loss did not improve from 0.79441
# Epoch 7/20
# 11/11 [==============================] - 35s 3s/step - loss: 0.7399 - categorical_accuracy: 0.7340 - val_loss: 3.6067 - val_categorical_accuracy: 0.2500
#
# Epoch 00007: val_loss did not improve from 0.79441
# Epoch 8/20
# 11/11 [==============================] - 31s 3s/step - loss: 0.6529 - categorical_accuracy: 0.7861 - val_loss: 3.9369 - val_categorical_accuracy: 0.1250
#
# Epoch 00008: val_loss did not improve from 0.79441
# Epoch 9/20
# 11/11 [==============================] - 34s 3s/step - loss: 0.6088 - categorical_accuracy: 0.7647 - val_loss: 2.5291 - val_categorical_accuracy: 0.5000
#
# Epoch 00009: val_loss did not improve from 0.79441
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/20
# 11/11 [==============================] - 33s 3s/step - loss: 0.4956 - categorical_accuracy: 0.8182 - val_loss: 3.4673 - val_categorical_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.79441
# Epoch 11/20
# 11/11 [==============================] - 30s 3s/step - loss: 0.5164 - categorical_accuracy: 0.8021 - val_loss: 1.8746 - val_categorical_accuracy: 0.3750
#
# Epoch 00011: val_loss did not improve from 0.79441
# Epoch 00011: early stopping

# %%
plotModelHistory(model4_history)
# Out:
# Max. Training Accuracy 0.8181818127632141
# Max. Validaiton Accuracy 0.5

# %% [markdown]
# <h3>Model 5: Frames:20, Epocs-20, BS-64, reduced kernel to (2,2,2), switching BatchNormalization before MaxPooling</h3>

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model5 = Sequential([
    Conv3D(16, make3dFilter(2), padding='same', activation='relu', input_shape=inputShape),
    BatchNormalization(),
    MaxPooling3D(make3dFilter(2)),

    Conv3D(32, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(64, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(128, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Flatten(),
    Dense(256, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.3),

    Dense(128, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_3d5")
model5.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model5.summary())

model5_history = model5.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_27 (Conv3D)           (None, 20, 100, 100, 16)  400
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 20, 100, 100, 16)  64
# _________________________________________________________________
# max_pooling3d_27 (MaxPooling (None, 10, 50, 50, 16)    0
# _________________________________________________________________
# conv3d_28 (Conv3D)           (None, 10, 50, 50, 32)    4128
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 10, 50, 50, 32)    128
# _________________________________________________________________
# max_pooling3d_28 (MaxPooling (None, 5, 25, 25, 32)     0
# _________________________________________________________________
# conv3d_29 (Conv3D)           (None, 5, 25, 25, 64)     16448
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 5, 25, 25, 64)     256
# _________________________________________________________________
# max_pooling3d_29 (MaxPooling (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# conv3d_30 (Conv3D)           (None, 2, 12, 12, 128)    65664
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 2, 12, 12, 128)    512
# _________________________________________________________________
# max_pooling3d_30 (MaxPooling (None, 1, 6, 6, 128)      0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               1179904
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_26 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 1,301,045
# Trainable params: 1,300,565
# Non-trainable params: 480
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 2.8553 - categorical_accuracy: 0.3017 Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# 11/11 [==============================] - 130s 13s/step - loss: 2.8553 - categorical_accuracy: 0.3017 - val_loss: 1.5975 - val_categorical_accuracy: 0.3400
#
# Epoch 00001: val_loss did not improve from 0.79441
# Epoch 2/20
# 11/11 [==============================] - 57s 6s/step - loss: 0.9703 - categorical_accuracy: 0.6324 - val_loss: 2.5303 - val_categorical_accuracy: 0.0781
#
# Epoch 00002: val_loss did not improve from 0.79441
# Epoch 3/20
# 11/11 [==============================] - 56s 6s/step - loss: 0.8438 - categorical_accuracy: 0.6917 - val_loss: 2.8290 - val_categorical_accuracy: 0.1607
#
# Epoch 00003: val_loss did not improve from 0.79441
# Epoch 4/20
# 11/11 [==============================] - 46s 5s/step - loss: 0.8264 - categorical_accuracy: 0.7082 - val_loss: 2.8177 - val_categorical_accuracy: 0.1562
#
# Epoch 00004: val_loss did not improve from 0.79441
# Epoch 5/20
# 11/11 [==============================] - 39s 4s/step - loss: 0.4403 - categorical_accuracy: 0.8421 - val_loss: 3.6296 - val_categorical_accuracy: 0.2500
#
# Epoch 00005: val_loss did not improve from 0.79441
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/20
# 11/11 [==============================] - 35s 3s/step - loss: 0.5732 - categorical_accuracy: 0.7895 - val_loss: 2.9646 - val_categorical_accuracy: 0.1250
#
# Epoch 00006: val_loss did not improve from 0.79441
# Epoch 7/20
# 11/11 [==============================] - 37s 4s/step - loss: 0.3723 - categorical_accuracy: 0.8522 - val_loss: 3.6826 - val_categorical_accuracy: 0.5000
#
# Epoch 00007: val_loss did not improve from 0.79441
# Epoch 8/20
# 11/11 [==============================] - 31s 3s/step - loss: 0.2680 - categorical_accuracy: 0.9091 - val_loss: 5.6241 - val_categorical_accuracy: 0.2500
#
# Epoch 00008: val_loss did not improve from 0.79441
# Epoch 9/20
# 11/11 [==============================] - 30s 3s/step - loss: 0.2110 - categorical_accuracy: 0.9733 - val_loss: 5.4343 - val_categorical_accuracy: 0.2500
#
# Epoch 00009: val_loss did not improve from 0.79441
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/20
# 11/11 [==============================] - 32s 3s/step - loss: 0.2394 - categorical_accuracy: 0.9198 - val_loss: 6.2669 - val_categorical_accuracy: 0.2500
#
# Epoch 00010: val_loss did not improve from 0.79441
# Epoch 11/20
# 11/11 [==============================] - 28s 3s/step - loss: 0.1907 - categorical_accuracy: 0.9519 - val_loss: 4.9745 - val_categorical_accuracy: 0.1250
#
# Epoch 00011: val_loss did not improve from 0.79441
# Epoch 00011: early stopping

# %%
plotModelHistory(model5_history)
# Out:
# Max. Training Accuracy 0.9732620120048523
# Max. Validaiton Accuracy 0.5

# %% [markdown]
# <h3>Model 6: Switching Model architecture to Conv2D+LSTM</h3>

# %%
n_frames = 20
num_epochs = 30
batch_size = 32

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model6 = Sequential([
    TimeDistributed(Conv2D(16, make2dFilter(3), padding='same', activation='relu'), input_shape=inputShape),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(32, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(64, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(128, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(256, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Flatten()),
    LSTM(256),
    Dropout(0.2),

    Dense(256, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_2d_lstm")
model6.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model6.summary())

model6_history = model6.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_2d_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 20, 100, 100, 16)  448
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 100, 100, 16)  64
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 50, 50, 16)    0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 20, 50, 50, 32)    4640
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 20, 50, 50, 32)    128
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 20, 25, 25, 32)    0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 20, 25, 25, 64)    18496
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 20, 25, 25, 64)    256
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 20, 12, 12, 64)    0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 20, 12, 12, 128)   73856
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 20, 12, 12, 128)   512
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 20, 6, 6, 128)     0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 20, 6, 6, 256)     295168
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 20, 6, 6, 256)     1024
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 20, 3, 3, 256)     0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 20, 2304)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               2622464
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 3,084,133
# Trainable params: 3,083,141
# Non-trainable params: 992
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 32
# Epoch 1/30
# 21/21 [==============================] - ETA: 0s - loss: 1.3379 - categorical_accuracy: 0.4344Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 32
# 21/21 [==============================] - 123s 6s/step - loss: 1.3379 - categorical_accuracy: 0.4344 - val_loss: 1.6147 - val_categorical_accuracy: 0.1300
#
# Epoch 00001: val_loss did not improve from 0.79441
# Epoch 2/30
# 21/21 [==============================] - 76s 4s/step - loss: 1.1260 - categorical_accuracy: 0.5383 - val_loss: 1.7721 - val_categorical_accuracy: 0.1250
#
# Epoch 00002: val_loss did not improve from 0.79441
# Epoch 3/30
# 21/21 [==============================] - 68s 3s/step - loss: 1.0045 - categorical_accuracy: 0.5714 - val_loss: 1.6930 - val_categorical_accuracy: 0.1875
#
# Epoch 00003: val_loss did not improve from 0.79441
# Epoch 4/30
# 21/21 [==============================] - 67s 3s/step - loss: 0.9040 - categorical_accuracy: 0.6466 - val_loss: 1.5521 - val_categorical_accuracy: 0.2500
#
# Epoch 00004: val_loss did not improve from 0.79441
# Epoch 5/30
# 21/21 [==============================] - 55s 3s/step - loss: 0.8767 - categorical_accuracy: 0.6471 - val_loss: 2.4277 - val_categorical_accuracy: 0.1875
#
# Epoch 00005: val_loss did not improve from 0.79441
# Epoch 6/30
# 21/21 [==============================] - 61s 3s/step - loss: 0.8165 - categorical_accuracy: 0.6807 - val_loss: 2.4846 - val_categorical_accuracy: 0.1875
#
# Epoch 00006: val_loss did not improve from 0.79441
# Epoch 7/30
# 21/21 [==============================] - 58s 3s/step - loss: 0.7000 - categorical_accuracy: 0.7227 - val_loss: 1.6964 - val_categorical_accuracy: 0.2500
#
# Epoch 00007: val_loss did not improve from 0.79441
# Epoch 8/30
# 21/21 [==============================] - 56s 3s/step - loss: 0.6939 - categorical_accuracy: 0.7199 - val_loss: 1.8563 - val_categorical_accuracy: 0.1875
#
# Epoch 00008: val_loss did not improve from 0.79441
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 9/30
# 21/21 [==============================] - 60s 3s/step - loss: 0.5620 - categorical_accuracy: 0.8039 - val_loss: 2.2045 - val_categorical_accuracy: 0.1250
#
# Epoch 00009: val_loss did not improve from 0.79441
# Epoch 10/30
# 21/21 [==============================] - 62s 3s/step - loss: 0.5092 - categorical_accuracy: 0.8179 - val_loss: 2.1613 - val_categorical_accuracy: 0.1875
#
# Epoch 00010: val_loss did not improve from 0.79441
# Epoch 11/30
# 21/21 [==============================] - 59s 3s/step - loss: 0.4051 - categorical_accuracy: 0.8459 - val_loss: 2.4176 - val_categorical_accuracy: 0.2500
#
# Epoch 00011: val_loss did not improve from 0.79441
# Epoch 12/30
# 21/21 [==============================] - 59s 3s/step - loss: 0.4082 - categorical_accuracy: 0.8487 - val_loss: 2.5715 - val_categorical_accuracy: 0.1875
#
# Epoch 00012: val_loss did not improve from 0.79441
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 13/30
# 21/21 [==============================] - 61s 3s/step - loss: 0.3572 - categorical_accuracy: 0.8711 - val_loss: 2.7102 - val_categorical_accuracy: 0.0625
#
# Epoch 00013: val_loss did not improve from 0.79441
# Epoch 14/30
# 21/21 [==============================] - 63s 3s/step - loss: 0.2823 - categorical_accuracy: 0.8992 - val_loss: 2.1970 - val_categorical_accuracy: 0.3125
#
# Epoch 00014: val_loss did not improve from 0.79441
# Epoch 00014: early stopping

# %%
plotModelHistory(model6_history)
# Out:
# Max. Training Accuracy 0.8991596698760986
# Max. Validaiton Accuracy 0.3125

# %% [markdown]
# <h3>Model 7: Transfer Learning (MobileNet) with LSTM</h3>

# %%
from tensorflow.keras.applications import mobilenet

# %%
mobilenet = mobilenet.MobileNet(weights='imagenet', include_top=False)

n_frames = 20
num_epochs = 30
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model7 = Sequential([
    TimeDistributed(mobilenet, input_shape=inputShape)
], name="mobilenet_lstm")

for layer in model7.layers:
    layer.trainable = False

model7.add(TimeDistributed(BatchNormalization()))
model7.add(TimeDistributed(MaxPooling2D(make2dFilter(2))))
model7.add(TimeDistributed(Flatten()))

model7.add(LSTM(256))
model7.add(Dropout(0.2))

model7.add(Dense(256,activation='relu'))
model7.add(Dropout(0.2))

model7.add(Dense(5, activation='softmax'))

model7.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model7.summary())

model7_history = model7.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "mobilenet_lstm"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_16 (TimeDis (None, 20, 3, 3, 1024)    3228864
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 20, 3, 3, 1024)    4096
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 20, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 20, 1024)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               1311744
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 4,611,781
# Trainable params: 1,380,869
# Non-trainable params: 3,230,912
# _________________________________________________________________
# None
# Source path =  ../input/gesturerecognition/Project_data/train ; batch size = 64
# Epoch 1/30
# 11/11 [==============================] - ETA: 0s - loss: 1.3870 - categorical_accuracy: 0.4193 Source path =  ../input/gesturerecognition/Project_data/val ; batch size = 64
# 11/11 [==============================] - 141s 14s/step - loss: 1.3870 - categorical_accuracy: 0.4193 - val_loss: 1.2212 - val_categorical_accuracy: 0.5700
#
# Epoch 00001: val_loss did not improve from 0.79441
# Epoch 2/30
# 11/11 [==============================] - 59s 6s/step - loss: 0.6909 - categorical_accuracy: 0.7708 - val_loss: 0.8693 - val_categorical_accuracy: 0.6406
#
# Epoch 00002: val_loss did not improve from 0.79441
# Epoch 3/30
# 11/11 [==============================] - 54s 5s/step - loss: 0.6058 - categorical_accuracy: 0.7708 - val_loss: 0.7578 - val_categorical_accuracy: 0.7321
#
# Epoch 00003: val_loss improved from 0.79441 to 0.75780, saving model to model_init_2023-02-0606_01_12.245131/model-00003-0.60582-0.77075-0.75780-0.73214.h5
# Epoch 4/30
# 11/11 [==============================] - 47s 5s/step - loss: 0.4876 - categorical_accuracy: 0.8627 - val_loss: 0.7552 - val_categorical_accuracy: 0.7500
#
# Epoch 00004: val_loss improved from 0.75780 to 0.75516, saving model to model_init_2023-02-0606_01_12.245131/model-00004-0.48761-0.86266-0.75516-0.75000.h5
# Epoch 5/30
# 11/11 [==============================] - 43s 4s/step - loss: 0.2936 - categorical_accuracy: 0.9091 - val_loss: 1.2812 - val_categorical_accuracy: 0.4688
#
# Epoch 00005: val_loss did not improve from 0.75516
# Epoch 6/30
# 11/11 [==============================] - 36s 4s/step - loss: 0.2781 - categorical_accuracy: 0.9139 - val_loss: 1.0772 - val_categorical_accuracy: 0.7500
#
# Epoch 00006: val_loss did not improve from 0.75516
# Epoch 7/30
# 11/11 [==============================] - 36s 4s/step - loss: 0.2585 - categorical_accuracy: 0.9015 - val_loss: 1.2572 - val_categorical_accuracy: 0.5000
#
# Epoch 00007: val_loss did not improve from 0.75516
# Epoch 8/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.1948 - categorical_accuracy: 0.9251 - val_loss: 0.9985 - val_categorical_accuracy: 0.7500
#
# Epoch 00008: val_loss did not improve from 0.75516
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 9/30
# 11/11 [==============================] - 29s 3s/step - loss: 0.1329 - categorical_accuracy: 0.9626 - val_loss: 0.3837 - val_categorical_accuracy: 0.8750
#
# Epoch 00009: val_loss improved from 0.75516 to 0.38370, saving model to model_init_2023-02-0606_01_12.245131/model-00009-0.13294-0.96257-0.38370-0.87500.h5
# Epoch 10/30
# 11/11 [==============================] - 32s 3s/step - loss: 0.0929 - categorical_accuracy: 0.9893 - val_loss: 0.4479 - val_categorical_accuracy: 0.8750
#
# Epoch 00010: val_loss did not improve from 0.38370
# Epoch 11/30
# 11/11 [==============================] - 32s 3s/step - loss: 0.0524 - categorical_accuracy: 0.9947 - val_loss: 0.8876 - val_categorical_accuracy: 0.7500
#
# Epoch 00011: val_loss did not improve from 0.38370
# Epoch 12/30
# 11/11 [==============================] - 29s 3s/step - loss: 0.0550 - categorical_accuracy: 0.9893 - val_loss: 0.3888 - val_categorical_accuracy: 0.8750
#
# Epoch 00012: val_loss did not improve from 0.38370
# Epoch 13/30
# 11/11 [==============================] - 34s 3s/step - loss: 0.0565 - categorical_accuracy: 0.9786 - val_loss: 1.2286 - val_categorical_accuracy: 0.3750
#
# Epoch 00013: val_loss did not improve from 0.38370
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 14/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.0365 - categorical_accuracy: 1.0000 - val_loss: 0.8203 - val_categorical_accuracy: 0.6250
#
# Epoch 00014: val_loss did not improve from 0.38370
# Epoch 15/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.0380 - categorical_accuracy: 0.9947 - val_loss: 0.5780 - val_categorical_accuracy: 0.7500
#
# Epoch 00015: val_loss did not improve from 0.38370
# Epoch 16/30
# 11/11 [==============================] - 32s 3s/step - loss: 0.0279 - categorical_accuracy: 1.0000 - val_loss: 0.3556 - val_categorical_accuracy: 1.0000
#
# Epoch 00016: val_loss improved from 0.38370 to 0.35556, saving model to model_init_2023-02-0606_01_12.245131/model-00016-0.02793-1.00000-0.35556-1.00000.h5
# Epoch 17/30
# 11/11 [==============================] - 32s 3s/step - loss: 0.0367 - categorical_accuracy: 0.9947 - val_loss: 2.0791 - val_categorical_accuracy: 0.5000
#
# Epoch 00017: val_loss did not improve from 0.35556
# Epoch 18/30
# 11/11 [==============================] - 29s 3s/step - loss: 0.0359 - categorical_accuracy: 1.0000 - val_loss: 0.2404 - val_categorical_accuracy: 0.8750
#
# Epoch 00018: val_loss improved from 0.35556 to 0.24042, saving model to model_init_2023-02-0606_01_12.245131/model-00018-0.03587-1.00000-0.24042-0.87500.h5
# Epoch 19/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.0351 - categorical_accuracy: 1.0000 - val_loss: 0.4356 - val_categorical_accuracy: 0.8750
#
# Epoch 00019: val_loss did not improve from 0.24042
# Epoch 20/30
# 11/11 [==============================] - 30s 3s/step - loss: 0.0303 - categorical_accuracy: 1.0000 - val_loss: 2.3463 - val_categorical_accuracy: 0.2500
#
# Epoch 00020: val_loss did not improve from 0.24042
# Epoch 21/30
# 11/11 [==============================] - 34s 3s/step - loss: 0.0264 - categorical_accuracy: 1.0000 - val_loss: 0.7379 - val_categorical_accuracy: 0.6250
#
# Epoch 00021: val_loss did not improve from 0.24042
# Epoch 22/30
# 11/11 [==============================] - 33s 3s/step - loss: 0.0214 - categorical_accuracy: 1.0000 - val_loss: 1.2872 - val_categorical_accuracy: 0.6250
#
# Epoch 00022: val_loss did not improve from 0.24042
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 23/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.0228 - categorical_accuracy: 0.9947 - val_loss: 0.9707 - val_categorical_accuracy: 0.7500
#
# Epoch 00023: val_loss did not improve from 0.24042
# Epoch 24/30
# 11/11 [==============================] - 32s 3s/step - loss: 0.0251 - categorical_accuracy: 1.0000 - val_loss: 1.4750 - val_categorical_accuracy: 0.6250
#
# Epoch 00024: val_loss did not improve from 0.24042
# Epoch 25/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.0298 - categorical_accuracy: 1.0000 - val_loss: 2.0935 - val_categorical_accuracy: 0.5000
#
# Epoch 00025: val_loss did not improve from 0.24042
# Epoch 26/30
# 11/11 [==============================] - 30s 3s/step - loss: 0.0256 - categorical_accuracy: 0.9947 - val_loss: 0.4775 - val_categorical_accuracy: 0.8750
#
# Epoch 00026: val_loss did not improve from 0.24042
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 27/30
# 11/11 [==============================] - 32s 3s/step - loss: 0.0344 - categorical_accuracy: 0.9893 - val_loss: 0.7657 - val_categorical_accuracy: 0.6250
#
# Epoch 00027: val_loss did not improve from 0.24042
# Epoch 28/30
# 11/11 [==============================] - 31s 3s/step - loss: 0.0327 - categorical_accuracy: 1.0000 - val_loss: 0.8760 - val_categorical_accuracy: 0.7500
#
# Epoch 00028: val_loss did not improve from 0.24042
# Epoch 00028: early stopping

# %%
plotModelHistory(model7_history)
# Out:
# Max. Training Accuracy 1.0
# Max. Validaiton Accuracy 1.0

# %% [markdown]
# <h2>After doing all the experiments, we finalized Model 7 - Transfer Learning (MobileNet) with LSTM, which giving best results.</h2>
#
# **Reason:**
#
# **- (Training Accuracy : 100%, Validation Accuracy : 100%)**
#
# **- Number of Parameters**
#
#     Total params: 4,611,781
#     Trainable params: 1,380,869
#     Non-trainable params: 3,230,912
#
# **- Learning rate gradually decreacing after 8 Epoch**
#
# **The best weights of CNN-LSTM: model-00020-0.19649-0.93514-0.45695-0.85000.h5 (29 MB). we considered this weight for model testing, Let's have look at the performance below**

# %%
# Downloading .h5 file of best result for submission.
import time
from keras.models import load_model
model = load_model('model_init_2023-02-0606_01_12.245131/model-00018-0.03587-1.00000-0.24042-0.87500.h5')
